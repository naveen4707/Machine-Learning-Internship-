# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install tensorflow pillow

# %%
import os
os.listdir("/content/drive/MyDrive/Naveen")
# Out:
# ['IMG-20251210-WA0058.jpg',
#  'IMG-20251210-WA0056.jpg',
#  'IMG-20251210-WA0059.jpg',
#  'IMG-20251210-WA0065.jpg',
#  'IMG-20251210-WA0066.jpg',
#  'IMG-20251210-WA0061.jpg',
#  'IMG-20251210-WA0064.jpg',
#  'IMG-20251210-WA0052.jpg',
#  'IMG-20251210-WA0060.jpg',
#  'IMG-20251210-WA0063.jpg',
#  'IMG-20251210-WA0057.jpg',
#  'IMG-20251210-WA0053.jpg',
#  'IMG-20251210-WA0055.jpg',
#  'IMG-20251210-WA0062.jpg']

# %%
input_folder = "/content/drive/MyDrive/Naveen/"

# %%
"/content/drive/MyDrive/Naveen/"
# Out:
# '/content/drive/MyDrive/Ragul/'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
import os

# Input and output folder
input_folder = "/content/drive/MyDrive/Naveen/"
output_folder = "/content/drive/MyDrive/Naveen_Augmented/"
os.makedirs(output_folder, exist_ok=True)

datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    brightness_range=[0.5, 1.5]
)

for filename in os.listdir(input_folder):
    img_path = os.path.join(input_folder, filename)
    img = load_img(img_path)
    img_array = img_to_array(img)
    img_array = img_array.reshape((1,) + img_array.shape)

    i = 0
    for batch in datagen.flow(img_array, batch_size=1,
                              save_to_dir=output_folder,
                              save_prefix="aug",
                              save_format="jpg"):
        i += 1
        if i == 5:
            break

print("Augmentation Completed!")
# Out:
# Augmentation Completed!
