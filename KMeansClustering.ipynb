# %%
import numpy as np
X=np.array([
    [40,45],
    [42,43],
    [38,40],
    [75,78],
    [80,82],
    [78,72],
    [90,92],
    [88,89],
    [92,94]
])

# %%
from sklearn.cluster import KMeans
kmeans=KMeans(n_clusters=4,random_state=0)
kmeans.fit(X)
labels=kmeans.labels_
print(labels)
# Out:
# [1 1 1 0 0 3 2 2 2]

# %%
from matplotlib import pyplot as plt
plt.scatter(X[:,0],X[:,1],c=labels)
plt.scatter(
    kmeans.cluster_centers_[:,0],
    kmeans.cluster_centers_[:,1],
    marker='X',
    s=200
)
plt.xlabel("Maths Marks")
plt.ylabel("Science Marks")
plt.title("K-Means Clustering (K=3)")
plt.show()

# %%
import pickle

# Save the trained model
with open('Kmeans.pkl', 'wb') as f:
    pickle.dump(kmeans, f)

# Save the column names to ensure input matches exactly
model_features = ['Maths Marks', 'Science Marks']
with open('features1.pkl', 'wb') as f:
    pickle.dump(model_features, f)

print("Files saved successfully: titanic_model.pkl, features.pkl")
# Out:
# Files saved successfully: titanic_model.pkl, features.pkl
